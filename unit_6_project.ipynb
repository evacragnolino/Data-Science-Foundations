# %% [markdown]
# <a href="https://colab.research.google.com/github/evacragnolino/Data-Science-Foundations/blob/main/unit_6_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **What wins a NCAA Title?**
# (in the 3k)

# %% [markdown]
# The indoor 3k is an intresting event because it is the last distance event which means not a lot of people scratch it because it doesn't interfere with other events the atheletes may have qualified for. This means that a mix of mile runners, 5k runners, DMR runners and runners who have opted to be fresh for the 3k are all running it which makes for an intresting race. The flat 3k is also only ran indoors and not on the outdoor track.

# %%
import numpy as np
import pandas as pd
import arviz as az
import pymc as pm
import graphviz as gv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install bambi
# Out:
# Collecting bambi
#   Downloading bambi-0.17.2-py3-none-any.whl.metadata (8.9 kB)
# Collecting arviz_plots<1,>=0.8.0 (from bambi)
#   Downloading arviz_plots-0.8.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting formulae<0.7.0,>=0.6.0 (from bambi)
#   Downloading formulae-0.6.2-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from bambi) (0.21)
# Requirement already satisfied: matplotlib>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from bambi) (3.10.0)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from bambi) (2.2.2)
# Requirement already satisfied: pymc<6,>=5.27.0 in /usr/local/lib/python3.12/dist-packages (from bambi) (5.27.1)
# Collecting sparse<0.18,>=0.17.0 (from bambi)
#   Downloading sparse-0.17.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Collecting arviz-base<0.9.0,>=0.8.1 (from arviz_plots<1,>=0.8.0->bambi)
#   Downloading arviz_base-0.8.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting arviz-stats<0.9.0,>=0.8.0 (from arviz-stats[xarray]<0.9.0,>=0.8.0->arviz_plots<1,>=0.8.0->bambi)
#   Downloading arviz_stats-0.8.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.12/dist-packages (from formulae<0.7.0,>=0.6.0->bambi) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from formulae<0.7.0,>=0.6.0->bambi) (26.0)
# Requirement already satisfied: scipy>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from formulae<0.7.0,>=0.6.0->bambi) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->bambi) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->bambi) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->bambi) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->bambi) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->bambi) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->bambi) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->bambi) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->bambi) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->bambi) (2025.3)
# Requirement already satisfied: arviz>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from pymc<6,>=5.27.0->bambi) (0.22.0)
# Requirement already satisfied: cachetools>=4.2.1 in /usr/local/lib/python3.12/dist-packages (from pymc<6,>=5.27.0->bambi) (7.0.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from pymc<6,>=5.27.0->bambi) (3.1.2)
# Requirement already satisfied: pytensor<2.38.0,>=2.37.0 in /usr/local/lib/python3.12/dist-packages (from pymc<6,>=5.27.0->bambi) (2.37.0)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.12/dist-packages (from pymc<6,>=5.27.0->bambi) (13.9.4)
# Requirement already satisfied: threadpoolctl<4.0.0,>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pymc<6,>=5.27.0->bambi) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.12/dist-packages (from pymc<6,>=5.27.0->bambi) (4.15.0)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.12/dist-packages (from sparse<0.18,>=0.17.0->bambi) (0.60.0)
# Requirement already satisfied: setuptools>=60.0.0 in /usr/local/lib/python3.12/dist-packages (from arviz>=0.13.0->pymc<6,>=5.27.0->bambi) (75.2.0)
# Requirement already satisfied: xarray>=2023.7.0 in /usr/local/lib/python3.12/dist-packages (from arviz>=0.13.0->pymc<6,>=5.27.0->bambi) (2025.12.0)
# Requirement already satisfied: h5netcdf>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from arviz>=0.13.0->pymc<6,>=5.27.0->bambi) (1.8.1)
# Requirement already satisfied: xarray-einstats>=0.3 in /usr/local/lib/python3.12/dist-packages (from arviz>=0.13.0->pymc<6,>=5.27.0->bambi) (0.9.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.49->sparse<0.18,>=0.17.0->bambi) (0.43.0)
# Requirement already satisfied: filelock>=3.15 in /usr/local/lib/python3.12/dist-packages (from pytensor<2.38.0,>=2.37.0->pymc<6,>=5.27.0->bambi) (3.24.2)
# Requirement already satisfied: etuples in /usr/local/lib/python3.12/dist-packages (from pytensor<2.38.0,>=2.37.0->pymc<6,>=5.27.0->bambi) (0.3.10)
# Requirement already satisfied: logical-unification in /usr/local/lib/python3.12/dist-packages (from pytensor<2.38.0,>=2.37.0->pymc<6,>=5.27.0->bambi) (0.4.7)
# Requirement already satisfied: miniKanren in /usr/local/lib/python3.12/dist-packages (from pytensor<2.38.0,>=2.37.0->pymc<6,>=5.27.0->bambi) (1.0.5)
# Requirement already satisfied: cons in /usr/local/lib/python3.12/dist-packages (from pytensor<2.38.0,>=2.37.0->pymc<6,>=5.27.0->bambi) (0.4.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.9.0->bambi) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->pymc<6,>=5.27.0->bambi) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->pymc<6,>=5.27.0->bambi) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->pymc<6,>=5.27.0->bambi) (0.1.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.12/dist-packages (from logical-unification->pytensor<2.38.0,>=2.37.0->pymc<6,>=5.27.0->bambi) (0.12.1)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.12/dist-packages (from logical-unification->pytensor<2.38.0,>=2.37.0->pymc<6,>=5.27.0->bambi) (1.0.0)
# Downloading bambi-0.17.2-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.6/109.6 kB 5.0 MB/s eta 0:00:00
# Downloading arviz_plots-0.8.0-py3-none-any.whl (218 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.9/218.9 kB 13.2 MB/s eta 0:00:00
# Downloading formulae-0.6.2-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 3.8 MB/s eta 0:00:00
# Downloading sparse-0.17.0-py2.py3-none-any.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.4/259.4 kB 16.9 MB/s eta 0:00:00
# Downloading arviz_base-0.8.2-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 53.0 MB/s eta 0:00:00
# Downloading arviz_stats-0.8.0-py3-none-any.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.6/164.6 kB 13.0 MB/s eta 0:00:00
# Installing collected packages: sparse, arviz-stats, formulae, arviz-base, arviz_plots, bambi
# Successfully installed arviz-base-0.8.2 arviz-stats-0.8.0 arviz_plots-0.8.0 bambi-0.17.2 formulae-0.6.2 sparse-0.17.0

# %%
import bambi as bmb

# %%
import numpy as np
import pandas as pd
import arviz as az
import matplotlib.pyplot as plt

# %%
threeK = pd.read_csv('https://raw.githubusercontent.com/evacragnolino/Data-Science-Foundations/main/Unit%206%20data%20sheet%20-%20Sheet1%20(3).csv')

# %%
threeK
# Out:
#      place                 name eligibility            school     time  year  \
# 0        1         Ceili McCabe        SR-4     West Virginia  9:01.18  2025
# 1        2       Doris Lemngole        SO-2           Alabama  9:01.64  2025
# 2        3  Lexy Halladay-Lowry        SR-4               BYU  9:03.20  2025
# 3        4        Amina Maatoug        SR-4        Washington  9:03.34  2025
# 4        5        Grace Hartman        SO-2          NC State  9:03.37  2025
# ..     ...                  ...         ...               ...      ...   ...
# 98      11       Alsu Bogdanova        SR-4  Eastern Michigan  9:12.81  2018
# 99      12     Amy-Eloise Neale        SR-4        Washington  9:20.24  2018
# 100     13           Erin Clark        SR-4          Colorado  9:21.07  2018
# 101     14       Elinor Purrier        SR-4     New Hampshire  9:25.93  2018
# 102     15          Gina Sereno        SR-4          Michigan  9:39.81  2018
#
#      prior experiece  three k PR  mile PR    conf. result
# 0                   2     8:45.97   4:29.26           1.0
# 1                   1     8:41.83   4:36.80           1.0
# 2                   2     8:40.60   4:31.89           1.0
# 3                   2     8:46.20   4:26.39           1.0
# 4                   2     8:46.57   4:24.76           4.0
# ..                ...         ...       ...           ...
# 98                  0     9:05.81   4:41.15           2.0
# 99                  1     9:01.96   4:34.15           7.0
# 100                 2     9:05.72   4:48.06           2.0
# 101                 3     8:55.68   4:26.55           1.0
# 102                 1     9:01.62   4:36.68           5.0
#
# [103 rows x 10 columns]

# %% [markdown]
# My data is data from the 2018 NCAA indoor championships to the 2025 championships and includes the athlete, their school and their eligibility along with their 3k PR, their mile PR, their best result from the conference meet and their prior experience which is the years they have competed in past NCAA 3k finals.

# %%
sns.pairplot(threeK)

# %%
dag_b = gv.Digraph(comment='threeK_dag') #b for bikes

dag_b.node('Y', 'eligibility')
dag_b.node('P','prior experience')
dag_b.node('N','NCAA result')
dag_b.node('S', 'school')
dag_b.node('E','date')
dag_b.node('T','NCAA time')
dag_b.node('K', '3K PR')
dag_b.node('M','mile PR')
dag_b.node('C','conference result')

dag_b.edges(['YN', 'YP','PC','PN','SK','SM','SN','KC','MC','KN','MN','CN','TN','ET'])

dag_b

# %% [markdown]
# talk about why you chose each variable in the data set to cause what

# %%
import numpy as np
import pandas as pd
import arviz as az
import pymc as pm
import graphviz as gv
import matplotlib.pyplot as plt
import seaborn as sns

threeK = pd.read_csv('https://raw.githubusercontent.com/evacragnolino/Data-Science-Foundations/main/Unit%206%20data%20sheet%20-%20Sheet1%20(3).csv')

# Display the head of the DataFrame immediately after loading to check its content
print("DataFrame head after loading (original columns):")
print(threeK.head())
print("Original Columns:", threeK.columns.tolist())

# Standardize column names: strip whitespace, replace spaces with underscores, make lowercase
def clean_col_name(col_name):
    return col_name.strip().lower().replace(' ', '_').replace('.', '')

threeK.columns = [clean_col_name(col) for col in threeK.columns]

# Further specific renames/corrections after general cleaning
# Fix typo 'experiece' to 'experience' and standardize 'three_k_pr' to 'pr_3k', 'mile_pr' to 'mile_PR'
threeK.rename(columns={'prior_experiece': 'prior_experience', 'three_k_pr': 'pr_3k', 'mile_pr': 'mile_PR'}, inplace=True)

print("Columns after cleaning and specific renames:", threeK.columns.tolist())
print("DataFrame head after column cleaning:")
print(threeK.head())

# Function to convert time strings (MM:SS.ms) to total seconds
def convert_time_to_seconds(time_str):
    if pd.isna(time_str): # Handle NaN values if any before conversion
        return np.nan
    parts = str(time_str).split(':')
    if len(parts) == 2:
        minutes = float(parts[0])
        seconds_ms_str = parts[1]
        if '.' in seconds_ms_str:
            seconds_parts = seconds_ms_str.split('.')
            seconds = float(seconds_parts[0])
            milliseconds = float(seconds_parts[1]) / (10**(len(seconds_parts[1])))
            total_seconds = minutes * 60 + seconds + milliseconds
        else:
            total_seconds = minutes * 60 + float(seconds_ms_str)
        return total_seconds
    return np.nan # Return NaN for unparseable formats

# Apply the custom function to convert 'pr_3k' column to total seconds
threeK['pr_3k'] = threeK['pr_3k'].apply(convert_time_to_seconds)

# Apply the custom function to convert 'time' column to total seconds
threeK['time'] = threeK['time'].apply(convert_time_to_seconds)

# Convert 'place' and 'conf_result' to numeric as well
threeK['place'] = pd.to_numeric(threeK['place'], errors='coerce')
threeK['conf_result'] = pd.to_numeric(threeK['conf_result'], errors='coerce')

# Drop rows with NaNs in all relevant columns to ensure clean data for all models
# Using the new, clean column names
threeK.dropna(subset=['pr_3k', 'place', 'conf_result', 'mile_PR', 'prior_experience', 'eligibility', 'school'], inplace=True)
# Out:
# DataFrame head after loading (original columns):
#    place                 name eligibility         school     time  year  \
# 0      1         Ceili McCabe        SR-4  West Virginia  9:01.18  2025
# 1      2       Doris Lemngole        SO-2        Alabama  9:01.64  2025
# 2      3  Lexy Halladay-Lowry        SR-4            BYU  9:03.20  2025
# 3      4        Amina Maatoug        SR-4     Washington  9:03.34  2025
# 4      5        Grace Hartman        SO-2       NC State  9:03.37  2025
#
#    prior experiece  three k PR  mile PR    conf. result
# 0                 2     8:45.97   4:29.26           1.0
# 1                 1     8:41.83   4:36.80           1.0
# 2                 2     8:40.60   4:31.89           1.0
# 3                 2     8:46.20   4:26.39           1.0
# 4                 2     8:46.57   4:24.76           4.0
# Original Columns: ['place', 'name', 'eligibility', 'school', 'time', 'year', 'prior experiece ', 'three k PR ', 'mile PR  ', 'conf. result']
# Columns after cleaning and specific renames: ['place', 'name', 'eligibility', 'school', 'time', 'year', 'prior_experience', 'pr_3k', 'mile_PR', 'conf_result']
# DataFrame head after column cleaning:
#    place                 name eligibility         school     time  year  \
# 0      1         Ceili McCabe        SR-4  West Virginia  9:01.18  2025
# 1      2       Doris Lemngole        SO-2        Alabama  9:01.64  2025
# 2      3  Lexy Halladay-Lowry        SR-4            BYU  9:03.20  2025
# 3      4        Amina Maatoug        SR-4     Washington  9:03.34  2025
# 4      5        Grace Hartman        SO-2       NC State  9:03.37  2025
#
#    prior_experience    pr_3k  mile_PR  conf_result
# 0                 2  8:45.97  4:29.26          1.0
# 1                 1  8:41.83  4:36.80          1.0
# 2                 2  8:40.60  4:31.89          1.0
# 3                 2  8:46.20  4:26.39          1.0
# 4                 2  8:46.57  4:24.76          4.0

# %%
#we put the priors that aren't normal or half normal with mean 0 and sigma 1
#in a dict
priors ={"pr_3k" : bmb.Prior("Normal", mu=0,sigma=10), "sigma" : bmb.Prior("HalfNormal",sigma=10)}

#This creates a skeleton of the model; it hasn't run MCMC or created a posterior yet
model_g3k_bmb = bmb.Model("place ~ pr_3k", threeK, family = "gaussian", priors=priors)

# %%
model_g3k_bmb
# Out:
#        Formula: place ~ pr_3k
#         Family: gaussian
#           Link: mu = identity
#   Observations: 93
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 7.5161, sigma: 10.7113)
#             pr_3k ~ Normal(mu: 0.0, sigma: 10.0)
#
#         Auxiliary parameters
#             sigma ~ HalfNormal(sigma: 10.0)

# %%
idata_g3k_bmb = model_g3k_bmb.fit(idata_kwargs={"log_likelihood":True})

# %%
bmb.interpret.plot_predictions(model_g3k_bmb, idata_g3k_bmb, "pr_3k")
plt.plot(threeK.pr_3k, threeK.place, "C2.", zorder=-3)

# %%
import matplotlib.ticker as mticker

bmb.interpret.plot_predictions(model_g3k_bmb, idata_g3k_bmb, "pr_3k", pps=True)
plt.plot(threeK.pr_3k, threeK.place, "C2.", zorder=-3)

def seconds_to_minutes_seconds(x, pos):
    minutes = int(x // 60)
    seconds = x % 60
    return f"{minutes:02d}:{seconds:05.2f}"

formatter = mticker.FuncFormatter(seconds_to_minutes_seconds)
plt.gca().xaxis.set_major_formatter(formatter)
plt.xlabel("3K PR (minutes:seconds)")
# I used gemini to make my x axis in minutes: seconds so its easier to read
# Out:
# Text(0.5, 0, '3K PR (minutes:seconds)')

# %%
model_3_conf_bmb = bmb.Model("place ~ pr_3k + conf_result", threeK, family="gaussian")
idata_3_conf_bmb = model_3_conf_bmb.fit(idata_kwargs={"log_likelihood":True})

# %%
model_3_conf_bmb
# Out:
#        Formula: place ~ pr_3k + conf_result
#         Family: gaussian
#           Link: mu = identity
#   Observations: 93
#         Priors:
#     target = mu
#         Common-level effects
#             Intercept ~ Normal(mu: 7.5161, sigma: 641.0437)
#             pr_3k ~ Normal(mu: 0.0, sigma: 1.1972)
#             conf_result ~ Normal(mu: 0.0, sigma: 6.5882)
#
#         Auxiliary parameters
#             sigma ~ HalfStudentT(nu: 4.0, sigma: 4.2845)
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %%
bmb.interpret.plot_predictions(model_3_conf_bmb, idata_3_conf_bmb, ["pr_3k", "conf_result"],

                               # take out subplot
                               legend=False,
                               fig_kwargs={"sharey":True, "sharex":True})
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  array([<Axes: xlabel='pr_3k', ylabel='place'>], dtype=object))

# %%
cmp_df_bmb = az.compare( {"multi_lin":idata_g3k_bmb,"single_lin":idata_3_conf_bmb} )
cmp_df_bmb
# Out:
#             rank    elpd_loo     p_loo  elpd_diff  weight        se       dse  \
# multi_lin      0 -260.958984  2.295059    0.00000     1.0  5.125983  0.000000
# single_lin     1 -261.527625  2.868684    0.56864     0.0  5.168568  0.490941
#
#             warning scale
# multi_lin     False   log
# single_lin    False   log

# %%
az.plot_compare(cmp_df_bmb)
# Out:
# <Axes: title={'center': 'Model comparison\nhigher is better'}, xlabel='elpd_loo (log)', ylabel='ranked models'>

# %% [markdown]
# The multi variable model predicts result at the NCAA championship better!

# %%
threeKallinter = bmb.Model(
    "place ~ pr_3k + conf_result + mile_PR + eligibility + school + prior_experience + pr_3k:conf_result + pr_3k:mile_PR + pr_3k:prior_experience + pr_3k:school + conf_result:mile_PR ",
    threeK, family="gaussian")
idata_threeKallinter = threeKallinter.fit(idata_kwargs={"log_likelihood":True})
# Out:
#
#   Progress                    Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ━━━━━━━━━━━━━━━╸━━━━━━━━━   1260    0             0.004       511          7.30 drawss/s    0:02:52   0:01:22
#   ━━━━━━━━━━━━━━━━━━━━━━━━━   0       0             0.000       0            0.00 draws/s     0:02:52   -:--:--

# %%
threeKallvars = bmb.Model(
    "place ~ pr_3k + conf_result + mile_PR + eligibility + school + prior_experience",
    threeK, family="gaussian")
idata_threeKallvars = threeKallvars.fit(idata_kwargs={"log_likelihood":True})

# %%
threeK_MCP = bmb.Model(
    "place ~ conf_result + mile_PR + prior_experience",
    threeK, family="gaussian")
idata_threeK_MCP = threeK_MCP.fit(idata_kwargs={"log_likelihood":True})

# %%
threeK_MCPi = bmb.Model(
    "place ~ conf_result + mile_PR + prior_experience + conf_result:mile_PR + conf_result:prior_experience",
    threeK, family="gaussian")
idata_threeK_MCPi = threeK_MCPi.fit(idata_kwargs={"log_likelihood":True})

# %%
threeK_mypick = bmb.Model(
    "place ~ conf_result + mile_PR  + pr_3k + conf_result:mile_PR",
    threeK, family="gaussian")
idata_threeK_mypick = threeK_mypick.fit(idata_kwargs={"log_likelihood":True})

# %%
threeK_SKMi = bmb.Model(
    "place ~ pr_3k + school + mile_PR  + pr_3k:mile_PR + pr_3k:school ",
    threeK, family="gaussian")
idata_threeK_SKMi = threeK_SKMi.fit(idata_kwargs={"log_likelihood":True})

# %%
cmp_threeK_bmb = az.compare( {"3k PR":idata_g3k_bmb,"3k + conf.":idata_3_conf_bmb,"allinter":idata_threeKallinter,"allvar":idata_threeKallvars,"mile_conf_experience":idata_threeK_MCP,"mile_conf_experience_i":idata_threeK_MCPi,"mypick_CKPMi":idata_threeK_mypick,"3k_school_mile_i":idata_threeK_SKMi } )
cmp_threeK_bmb
# Out:
# /usr/local/lib/python3.12/dist-packages/arviz/stats/stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.70 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/arviz/stats/stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.70 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/arviz/stats/stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.70 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/arviz/stats/stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.70 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/arviz/stats/stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.70 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/arviz/stats/stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.70 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
#                         rank    elpd_loo      p_loo  elpd_diff        weight  \
# allvar                     0 -226.794165  82.447543   0.000000  1.000000e+00
# 3k_school_mile_i           1 -241.898102  70.437510  15.103937  1.144329e-11
# mile_conf_experience       2 -242.786826  65.999588  15.992660  9.933387e-12
# allinter                   3 -254.021277  84.487400  27.227112  4.412470e-12
# mypick_CKPMi               4 -259.184924  69.584630  32.390758  2.456702e-12
# 3k PR                      5 -260.958984   2.295059  34.164819  3.888445e-12
# 3k + conf.                 6 -261.527625   2.868684  34.733459  3.695710e-12
# mile_conf_experience_i     7 -264.461584  71.821474  37.667419  0.000000e+00
#
#                               se       dse  warning scale
# allvar                  2.709927  0.000000     True   log
# 3k_school_mile_i        4.238190  3.649867     True   log
# mile_conf_experience    3.222766  3.354764     True   log
# allinter                1.632405  2.389811     True   log
# mypick_CKPMi            3.138456  3.151729     True   log
# 3k PR                   5.125983  5.748818    False   log
# 3k + conf.              5.168568  5.789103    False   log
# mile_conf_experience_i  2.289099  3.458069     True   log

# %% [markdown]
# I think with a lot of the models that included conference were wourse since some of the atheletes either did not race conference or the conferences vary so much in stregth so its very hard to compare across each one.

# %%
az.plot_compare(cmp_threeK_bmb)
# Out:
# <Axes: title={'center': 'Model comparison\nhigher is better'}, xlabel='elpd_loo (log)', ylabel='ranked models'>

# %%
bmb.interpret.plot_predictions(threeKallvars, idata_threeKallvars, ["pr_3k", "mile_PR"],
                               legend=False,
                               fig_kwargs={"sharey":True, "sharex":True})
plt.scatter(threeK.pr_3k, threeK.place, color='red', alpha=0.5, label='Actual data')

# %%
bmb.interpret.plot_predictions(threeK_SKMi, idata_threeK_SKMi, ["place", "mile_PR","pr_3k"],
                               legend=False,
                               fig_kwargs={"sharey":True, "sharex":True})

# %% [markdown]
# What single variable best predicts placing in the 3k final?

# %%
model_mile_bmb = bmb.Model("place ~ mile_PR", threeK, family = "gaussian", priors=priors)
idata_model_mile_bmb = model_mile_bmb.fit(idata_kwargs={"log_likelihood":True})

# %%
model_conf_bmb = bmb.Model("place ~ conf_result", threeK, family = "gaussian", priors=priors)
idata_model_conf_bmb = model_conf_bmb.fit(idata_kwargs={"log_likelihood":True})

# %%
model_e_bmb = bmb.Model("place ~ eligibility", threeK, family = "gaussian", priors=priors)
idata_model_e_bmb = model_e_bmb.fit(idata_kwargs={"log_likelihood":True})

# %%
model_pre_bmb = bmb.Model("place ~ prior_experience", threeK, family = "gaussian", priors=priors)
idata_model_pre_bmb = model_pre_bmb.fit(idata_kwargs={"log_likelihood":True})

# %%
model_school_bmb = bmb.Model("place ~ school", threeK, family = "gaussian", priors=priors)
idata_model_school_bmb = model_school_bmb.fit(idata_kwargs={"log_likelihood":True})

# %%
cmp_threeK_svar_bmb = az.compare( {"3k PR":idata_g3k_bmb," mile.":idata_model_mile_bmb,"conf":idata_model_conf_bmb,"eligibility":idata_model_e_bmb,"prevous experience":idata_model_pre_bmb,"school":idata_model_school_bmb } )
cmp_threeK_svar_bmb
# Out:
# /usr/local/lib/python3.12/dist-packages/arviz/stats/stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.70 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/arviz/stats/stats.py:797: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.70 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
#                     rank    elpd_loo      p_loo  elpd_diff        weight  \
#  mile.                 0 -244.636658  66.834726   0.000000  8.845139e-01
# 3k PR                  1 -260.958984   2.295059  16.322326  1.154861e-01
# conf                   2 -266.906462   1.945637  22.269804  0.000000e+00
# prevous experience     3 -269.941007   2.959706  25.304349  0.000000e+00
# eligibility            4 -270.316103   4.210166  25.679445  0.000000e+00
# school                 5 -283.696604  35.101775  39.059947  3.078537e-12
#
#                           se       dse  warning scale
#  mile.              4.952621  0.000000     True   log
# 3k PR               5.125983  6.911487    False   log
# conf                4.432832  6.283615    False   log
# prevous experience  4.734726  6.511354    False   log
# eligibility         4.671461  6.020335    False   log
# school              5.124310  6.333208     True   log

# %%
az.plot_compare(cmp_threeK_svar_bmb)
# Out:
# <Axes: title={'center': 'Model comparison\nhigher is better'}, xlabel='elpd_loo (log)', ylabel='ranked models'>

# %% [markdown]
# The athletes best mile is the best single variable predictor in the 3k even better than the 3k PR which they are racing. This is probably because championship races tend to start slower and be determined by fast finishes that makes them more like a mile race.
